# %% [markdown]
# ## Importing the standard libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the dataset

# %%
data = pd.read_csv('Data.csv')
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
## Dropping the missing values

# %%
data.dropna(inplace = True)
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# ## Split the data into X and y

# %%
X = data.drop('Purchased', axis = 1)
y = data['Purchased']

# %% [markdown]
# ## Performing train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
print(X_train)
# Out:
#    Country   Age   Salary
# 1    Spain  27.0  48000.0
# 3    Spain  38.0  61000.0
# 0   France  44.0  72000.0
# 5   France  35.0  58000.0
# 8  Germany  50.0  83000.0
# 9   France  37.0  67000.0

# %%
print(X_test)
# Out:
#    Country   Age   Salary
# 7   France  48.0  79000.0
# 2  Germany  30.0  54000.0

# %%
print(y_train)
# Out:
# 1    Yes
# 3     No
# 0     No
# 5    Yes
# 8     No
# 9    Yes
# Name: Purchased, dtype: object

# %%
print(y_test)
# Out:
# 7    Yes
# 2     No
# Name: Purchased, dtype: object

# %% [markdown]
# ## Feature Scaling
#
# - Note : Applied only on Numerical Columns

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train[['Age', 'Salary']] = scaler.fit_transform(X_train[['Age', 'Salary']])

# %%
X_train
# Out:
#    Country       Age    Salary
# 1    Spain -1.601191 -1.525234
# 3    Spain -0.069617 -0.347331
# 0   France  0.765787  0.649357
# 5   France -0.487319 -0.619155
# 8  Germany  1.601191  1.646045
# 9   France -0.208851  0.196317

# %%
X_test[['Age', 'Salary']] = scaler.fit_transform(X_test[['Age', 'Salary']])

# %%
X_test
# Out:
#    Country  Age  Salary
# 7   France  1.0     1.0
# 2  Germany -1.0    -1.0

# %% [markdown]
# ## Feature Scaling on titanic data

# %%
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# - Age, Fare are the columns on which Feature Scaling needs to applied

# %%
X = titanic.drop('Survived', axis = 1)
y = titanic['Survived']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train[['Age', 'Fare']] = scaler.fit_transform(X_train[['Age', 'Fare']])

# %%
X_train
# Out:
#      PassengerId  Pclass                                             Name  \
# 317          318       2                             Moraweck, Dr. Ernest
# 769          770       3                 Gronnestad, Mr. Daniel Danielsen
# 626          627       2                   Kirkland, Rev. Charles Leonard
# 48            49       3                              Samaan, Mr. Youssef
# 450          451       2                            West, Mr. Edwy Arthur
# ..           ...     ...                                              ...
# 523          524       1  Hippach, Mrs. Louis Albert (Ida Sophia Fischer)
# 135          136       2                               Richard, Mr. Emile
# 806          807       1                           Andrews, Mr. Thomas Jr
# 877          878       3                             Petroff, Mr. Nedelio
# 563          564       3                                Simmons, Mr. John
#
#         Sex       Age  SibSp  Parch           Ticket      Fare Cabin Embarked
# 317    male  1.690272      0      0            29011 -0.380947   NaN        S
# 769    male  0.159469      0      0             8471 -0.496275   NaN        S
# 626    male  1.899018      0      0           219533 -0.414701   NaN        Q
# 48     male       NaN      2      0             2662 -0.223850   NaN        C
# 450    male  0.437797      1      2       C.A. 34651 -0.099657   NaN        S
# ..      ...       ...    ...    ...              ...       ...   ...      ...
# 523  female  0.994452      0      1           111361  0.518754   B18        C
# 135    male -0.466769      0      0    SC/PARIS 2133 -0.359552   NaN        C
# 806    male  0.646543      0      0           112050 -0.667350   A36        S
# 877    male -0.745097      0      0           349212 -0.505823   NaN        S
# 563    male       NaN      0      0  SOTON/OQ 392082 -0.502668   NaN        S
#
# [712 rows x 11 columns]

# %%
X_test[['Age', 'Fare']] = scaler.fit_transform(X_test[['Age', 'Fare']])

# %%
X_test
# Out:
#      PassengerId  Pclass                                      Name     Sex  \
# 63            64       3                     Skoog, Master. Harald    male
# 719          720       3              Johnson, Mr. Malkolm Joackim    male
# 314          315       2                        Hart, Mr. Benjamin    male
# 624          625       3               Bowen, Mr. David John "Dai"    male
# 76            77       3                         Staneff, Mr. Ivan    male
# ..           ...     ...                                       ...     ...
# 517          518       3                         Ryan, Mr. Patrick    male
# 141          142       3                  Nysten, Miss. Anna Sofia  female
# 803          804       3           Thomas, Master. Assad Alexander    male
# 699          700       3  Humblen, Mr. Adolf Mathias Nicolai Olsen    male
# 585          586       1                       Taussig, Miss. Ruth  female
#
#           Age  SibSp  Parch        Ticket      Fare  Cabin Embarked
# 63  -1.699988      3      2        347088 -0.050244    NaN        S
# 719  0.221132      0      0        347062 -0.432602    NaN        S
# 314  0.883587      1      1  F.C.C. 13529 -0.081593    NaN        S
# 624 -0.573814      0      0         54636 -0.274434    NaN        S
# 76        NaN      0      0        349208 -0.430307    NaN        S
# ..        ...    ...    ...           ...       ...    ...      ...
# 517       NaN      0      0        371110 -0.121491    NaN        Q
# 141 -0.507568      0      0        347081 -0.433077    NaN        S
# 803 -1.937147      0      1          2625 -0.418510    NaN        C
# 699  0.817342      0      0        348121 -0.434977  F G63        S
# 585 -0.772551      0      2        110413  0.932961    E68        S
#
# [179 rows x 11 columns]
